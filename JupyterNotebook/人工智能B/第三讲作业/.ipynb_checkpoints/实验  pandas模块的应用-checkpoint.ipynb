# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1. DataFrame对象的操作

# %% [markdown]
# “Apple”、“Samsung”、 “Huawei”、 “Mi” 、“OPPO”五个公司在2019年四个季度的手机出货量（单位：百万），如下表所示，其中数据为随机产生的实验数据。使用pandas的Dataframe对象实现以下功能。
#
# ![image.png](attachment:image.png)

# %% [markdown]
# （1）创建如图所示的表格对象phone。行序号从1~5。列标签是"公司","第一季度","第二季度","第三季度","第四季度"，一共5条记录。
#
# 季度
# 公司	第一季度	第二季度	第三季度	第四季度
# Apple	51.9	57.9	48.7	50.4
# Samsung	69.7	64.6	41.7	51.7
# Huawei	31.7	58.6	59.2	47.9
# Mi	41.7	38.6	58.0	58.9
# OPPO	69.8	31.1	58.7	30.4

# %%
#方法一 使用列表创建
title = ["公司","第一季度","第二季度","第三季度","第四季度"]
recs = [["Apple",51.9,57.9,48.7,50.4],["Samsung",69.7,64.6,41.7,51.7],["Huawei",31.7,58.6,59.2,47.9],["Mi",41.7,38.6,58.0,58.9],["OPPO",69.8,31.1,58.7,30.4]]
phone = pd.DataFrame(title, recs)#
phone
# Out:
#                                    0
# Apple Samsung Huawei Mi   OPPO    公司
# 51.9  69.7    31.7   41.7 69.8  第一季度
# 57.9  64.6    58.6   38.6 31.1  第二季度
# 48.7  41.7    59.2   58.0 58.7  第三季度
# 50.4  51.7    47.9   58.9 30.4  第四季度

# %%
#方法二 使用字典创建
title = ["公司","第一季度","第二季度","第三季度","第四季度"]
gs = ["Apple","Samsung","Huawei","Mi","OPPO"]
s1 = [51.9,69.7,31.7,41.7,69.8]
s2 = [57.9,64.6,58.6,38.6,31.1]
s3 = [48.7,41.7,59.2,58.0,58.7]
s4 = [50.4,51.7,47.9,58.9,30.4]
d = dict(zip(title,[gs,s1,s2,s3,s4]))
phone = pd.DataFrame(d)#
phone
# Out:
#         公司  第一季度  第二季度  第三季度  第四季度
# 0    Apple  51.9  57.9  48.7  50.4
# 1  Samsung  69.7  64.6  41.7  51.7
# 2   Huawei  31.7  58.6  59.2  47.9
# 3       Mi  41.7  38.6  58.0  58.9
# 4     OPPO  69.8  31.1  58.7  30.4

# %% [markdown]
# (2)选择Huawei和Mi的第四季度数据增加10%

# %%
phone.loc[2,'第四季度'] = phone.loc[2,'第四季度'] * (1.1)
phone.loc[3,'第四季度'] = phone.loc[3,'第四季度'] * (1.1)
print(phone)

# %% [markdown]
# (3)所有Samsung的数据降低5%

# %%
phone.iloc[1,1:5] = phone.iloc[1,1:5] * 0.95
print(phone)

# %% [markdown]
# (4) 分别统计五个公司在2019年的手机出货总量

# %%
print(phone.iloc[0,1:5].sum(), phone.iloc[1,1:5].sum(),phone.iloc[2,1:5].sum(),phone.iloc[3,1:5].sum(),phone.iloc[4,1:5].sum())
# Out:
# 208.9 216.315 202.19 203.09000000000003 190.00000000000003

# %% [markdown]
# (5) 统计所有公司第一季度的手机总出货量和第四季度的手机总出货

# %%
print(phone['第一季度'].sum(), phone['第四季度'].sum())
# Out:
# 261.315 247.395

# %% [markdown]
# (6)找出每个季度出货量最大的公司名称（不是编号）

# %%
maxcom = []
maxnum = np.argmax(np.array(phone.iloc[:,1:5]),axis=0)
for i in maxnum:
    maxcom.append(phone.iloc[i,0])
print(maxcom)
# Out:
# ['OPPO', 'Samsung', 'Huawei', 'Mi']

# %% [markdown]
# # 2.数据文件的维护和统计

# %% [markdown]
# 2. 读取EMSI_JobChange_UK.CSV文件，完成以下分析。该文件给出了英国各城市 2011 年和 2014 年就业数据（按行业），由 EMSI，即 Economic Modeling Specialists Inc.（经济建模专家公司）提供。
# （1）读取EMSI_JobChange_UK.xlsx文件数据，创建为DataFrame数据对象。

# %%
df = pd.read_csv(r"F:\JupyterNotebook\人工智能B\第三讲作业\EMSI_JobChange_UK.csv") #
df
# Out:
#          City Country SIC Code  \
# 0    Aberdeen      UK        M
# 1    Aberdeen      UK        Q
# 2    Aberdeen      UK        G
# 3    Aberdeen      UK        N
# 4    Aberdeen      UK        B
# ..        ...     ...      ...
# 299   Swansea      UK        S
# 300   Swansea      UK        L
# 301   Swansea      UK        E
# 302   Swansea      UK        B
# 303   Swansea      UK        D
#
#                                               Industry  Jobs 2011  Jobs 2014
# 0    PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES      33510      34729
# 1              HUMAN HEALTH AND SOCIAL WORK ACTIVITIES      35520      34555
# 2    WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VE...      34231      34065
# 3        ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES      22344      29561
# 4                                 MINING AND QUARRYING      26210      28120
# ..                                                 ...        ...        ...
# 299                           OTHER SERVICE ACTIVITIES       3851       2915
# 300                             REAL ESTATE ACTIVITIES       2396       2673
# 301  WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND R...       1826       2135
# 302                               MINING AND QUARRYING        757       1058
# 303  ELECTRICITY, GAS, STEAM AND AIR CONDITIONING S...        484        607
#
# [304 rows x 6 columns]

# %% [markdown]
# （2）查询London市的SIC Code、Jobs 2011和Jobs 2014三列数据。

# %%
print(df.loc[df['City']=='London',['SIC Code','Jobs 2011','Jobs 2014']]) #
# Out:
#     SIC Code  Jobs 2011  Jobs 2014
# 171        M     531559     635137
# 172        G     546380     558659
# 173        N     451051     493531
# 174        Q     420193     461843
# 175        P     350060     373164
# 176        K     354350     360379
# 177        I     308886     345643
# 178        J     328204     342018
# 179        H     207971     214908
# 180        O     224450     207203
# 181        F     126488     160733
# 182        L     100275     148993
# 183        R     113673     127678
# 184        S     111935     111438
# 185        C     100183     106135
# 186        E      17151      19803
# 187        D       7325       5306
# 188        B       3037       4683
# 189        A       1000        809

# %%
#（3）添加两列："Change"列= Jobs 2014- Jobs 2011，"Change%"列=Change/ Jobs 2011。

# %%
df["Change"] = df.loc[:,'Jobs 2014'] - df.loc[:,'Jobs 2011'] #
df["Change%"] = df["Change"] / df["Jobs 2011"]
df
# Out:
#          City Country SIC Code  \
# 0    Aberdeen      UK        M
# 1    Aberdeen      UK        Q
# 2    Aberdeen      UK        G
# 3    Aberdeen      UK        N
# 4    Aberdeen      UK        B
# ..        ...     ...      ...
# 299   Swansea      UK        S
# 300   Swansea      UK        L
# 301   Swansea      UK        E
# 302   Swansea      UK        B
# 303   Swansea      UK        D
#
#                                               Industry  Jobs 2011  Jobs 2014  \
# 0    PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES      33510      34729
# 1              HUMAN HEALTH AND SOCIAL WORK ACTIVITIES      35520      34555
# 2    WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VE...      34231      34065
# 3        ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES      22344      29561
# 4                                 MINING AND QUARRYING      26210      28120
# ..                                                 ...        ...        ...
# 299                           OTHER SERVICE ACTIVITIES       3851       2915
# 300                             REAL ESTATE ACTIVITIES       2396       2673
# 301  WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND R...       1826       2135
# 302                               MINING AND QUARRYING        757       1058
# 303  ELECTRICITY, GAS, STEAM AND AIR CONDITIONING S...        484        607
#
#      Change   Change%
# 0      1219  0.036377
# 1      -965 -0.027168
# 2      -166 -0.004849
# 3      7217  0.322995
# 4      1910  0.072873
# ..      ...       ...
# 299    -936 -0.243054
# 300     277  0.115609
# 301     309  0.169222
# 302     301  0.397622
# 303     123  0.254132
#
# [304 rows x 8 columns]

# %%
#（4）删除Country列

# %%
df.drop(["Country"],axis = 1,inplace = True) #
df
# Out:
#          City SIC Code                                           Industry  \
# 0    Aberdeen        M  PROFESSIONAL, SCIENTIFIC AND TECHNICAL ACTIVITIES
# 1    Aberdeen        Q            HUMAN HEALTH AND SOCIAL WORK ACTIVITIES
# 2    Aberdeen        G  WHOLESALE AND RETAIL TRADE; REPAIR OF MOTOR VE...
# 3    Aberdeen        N      ADMINISTRATIVE AND SUPPORT SERVICE ACTIVITIES
# 4    Aberdeen        B                               MINING AND QUARRYING
# ..        ...      ...                                                ...
# 299   Swansea        S                           OTHER SERVICE ACTIVITIES
# 300   Swansea        L                             REAL ESTATE ACTIVITIES
# 301   Swansea        E  WATER SUPPLY; SEWERAGE, WASTE MANAGEMENT AND R...
# 302   Swansea        B                               MINING AND QUARRYING
# 303   Swansea        D  ELECTRICITY, GAS, STEAM AND AIR CONDITIONING S...
#
#      Jobs 2011  Jobs 2014  Change   Change%
# 0        33510      34729    1219  0.036377
# 1        35520      34555    -965 -0.027168
# 2        34231      34065    -166 -0.004849
# 3        22344      29561    7217  0.322995
# 4        26210      28120    1910  0.072873
# ..         ...        ...     ...       ...
# 299       3851       2915    -936 -0.243054
# 300       2396       2673     277  0.115609
# 301       1826       2135     309  0.169222
# 302        757       1058     301  0.397622
# 303        484        607     123  0.254132
#
# [304 rows x 7 columns]

# %%
#（5）查询教育行业（SIC Code:P）的城市就业情况，显示City 、Jobs 2011 、Jobs 2014 、 Change的数据，并按Change列由大到小排列

# %%
print(df.loc[df['SIC Code']=='P',["City","Jobs 2011","Jobs 2014","Change"]].sort_values(["Change"],ascending=False))#
# Out:
#                        City  Jobs 2011  Jobs 2014  Change
# 175                  London     350060     373164   23104
# 250               Sheffield     102511     110854    8343
# 155               Liverpool      89387      93868    4481
# 193              Manchester      98536     102235    3699
# 268  Southampton-Portsmouth      53678      55995    2317
# 78          Cardiff-Newport      57841      58746     905
# 40                 Brighton      34636      35141     505
# 135          Leeds-Bradford      59767      60061     294
# 212    Newcastle-Sunderland      75062      75068       6
# 288                 Swansea      19709      19696     -13
# 59                  Bristol      64049      63949    -100
# 6                  Aberdeen      17905      17082    -823
# 232        Nottingham-Derby      62493      61452   -1041
# 118                 Glasgow      58753      56502   -2251
# 98                Edinburgh      54674      50987   -3687
# 22               Birmingham      89792      84613   -5179
