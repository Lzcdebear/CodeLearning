# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1.统计分析（建议使用DataFrame实现）

# %% [markdown]
# (1)准备数据
# rainfalldata.csv文件中存放了多个城市12个月的降水量
# ![%E6%8D%95%E8%8E%B74.PNG](attachment:%E6%8D%95%E8%8E%B74.PNG)

# %% [markdown]
# #读入rainfalldata.csv文件到DataFrame对象

# %% [markdown]
# （1）求每个城市的平均降水量

# %%
df=pd.read_csv(r'F:\JupyterNotebook\人工智能B\第六讲作业\rainfalldata.csv',encoding='gbk')  #
print(df)
# Out:
#    地区  1月   2月   3月   4月   5月   6月   7月   8月   9月  10月  11月  12月
# 0  上海  52   20  104   60  199  167  158  211   14   92    2   14
# 1  北京   0    2    7    5   46   69  196  120  116   10    0    3
# 2  天津   0    0    4   13   60  115  216  199   51   44    4    0
# 3  喀什   1    0    2   41    3    4    6    1    3    5    0    3
# 4  西安   4    1   43   32   22   20   71   24   24   64    8    0
# 5  重庆  30   21   21   27  118  225  167   51   77  101   46   39
# 6  广州  42   71   78  104   71  219  275  316  168  305    6    5
# 7  韶关  67  140  115  136  134  470  128  120   17  128   22   30
# 8  海口  36   14   63   37  198  273  252  272  190  313  125   19

# %% [markdown]
# （2）求每个月的平均降水量

# %%
print(df.iloc[:,1:].mean(axis=0))        #
# Out:
# 1月      25.777778
# 2月      29.888889
# 3月      48.555556
# 4月      50.555556
# 5月      94.555556
# 6月     173.555556
# 7月     163.222222
# 8月     146.000000
# 9月      73.333333
# 10月    118.000000
# 11月     23.666667
# 12月     12.555556
# dtype: float64

# %% [markdown]
# （3）求每个城市最大降水量和最小降水量出现的月份

# %%
print(df.iloc[:,1:].astype('float64').idxmax(axis=1,skipna=True))         #
# Out:
# 0     8月
# 1     7月
# 2     7月
# 3     4月
# 4     7月
# 5     6月
# 6     8月
# 7     6月
# 8    10月
# dtype: object

# %%
np.array([df.loc[city,'1月':].astype("int").argmax()+1 for city in range(9)]) # not mine
# Out:
# array([ 8,  7,  7,  4,  7,  6,  8,  6, 10], dtype=int64)

# %%
print(df.iloc[:,1:].astype('float64').idxmax(axis=1,skipna=True))         #
# Out:
# 0     8月
# 1     7月
# 2     7月
# 3     4月
# 4     7月
# 5     6月
# 6     8月
# 7     6月
# 8    10月
# dtype: object

# %%
print(df.iloc[:,1:].astype('float64').idxmin(axis=1,skipna=True))         #
# Out:
# 0    11月
# 1     1月
# 2     1月
# 3     2月
# 4    12月
# 5     2月
# 6    12月
# 7     9月
# 8     2月
# dtype: object

# %%
np.array([df.loc[city,'1月':].astype("int").argmin()+1 for city in range(9)]) # not mine
# Out:
# array([11,  1,  1,  2, 12,  2, 12,  9,  2], dtype=int64)

# %% [markdown]
# (4)求出现降水量最高的城市

# %%
print(df.iloc[df.sum(axis=1).argmax() - 1,0])        #
# Out:
# '韶关'

# %% [markdown]
# # 2.使用matplotlib绘图

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %% [markdown]
# （1）绘制某家庭年各项消费占比的饼图。

# %%
#设置中文显示和字体

# %%
plt.rcParams['font.sans-serif'] = 'SimHei'  # 设置中文显示
plt.rcParams['font.size'] = 16

# %%
#设置画布尺寸为12*12英寸

# %%
plt.figure(figsize=(12, 12))  # 设置画布尺寸12*12英寸

# %%
#准备数据

# %%
Items = ['教育', '食品', '服装', '旅游', '保险', '其它']  # 定义饼图的标签
explode = [0.1, 0.01, 0.01, 0.01, 0.01, 0.01]  # 设定各项距离圆心距离
Expenses = [30000, 12000, 8000, 24000, 3500, 8000]

# %%
#绘制饼图

# %%
plt.pie(Expenses, explode=explode, labels=Items, autopct='%4.2f%%', shadow=True)  # 绘制饼图
plt.title('家庭年各项消费比较表')  #设置标题
plt.legend(Items, loc=(12/12,6/12))  #设置图例
plt.show()

# %% [markdown]
# （2）绘制散点图

# %%
#读取CSV文件Iris_plot.csv的数据到DataFrame

# %%
data = pd.read_csv(r'F:\JupyterNotebook\人工智能B\第六讲作业\Iris_plot.csv') #
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  class
# 0             5.1          3.5           1.4          0.2      0
# 1             4.9          3.0           1.4          0.2      0
# 2             4.7          3.2           1.3          0.2      0
# 3             4.6          3.1           1.5          0.2      0
# 4             5.0          3.6           1.4          0.2      0
# ..            ...          ...           ...          ...    ...
# 145           6.7          3.0           5.2          2.3      2
# 146           6.3          2.5           5.0          1.9      2
# 147           6.5          3.0           5.2          2.0      2
# 148           6.2          3.4           5.4          2.3      2
# 149           5.9          3.0           5.1          1.8      2
#
# [150 rows x 5 columns]

# %%
#准备数据

# %%
X = data['petal_length']  #准备x轴数据
Y = data['petal_width']   #准备y轴数据

# %%
#设置画布大小为12*10英寸

# %%
fig = plt.figure(figsize=(12,12))  #

# %%
#绘制散点图

# %%
plt.scatter(X[:50], Y[:50], color='green', marker='o', label='setosa')  # 前50个样本
plt.scatter(X[50:100], Y[50:100], color='blue', marker='x', label='versicolor')  # 中间50个
plt.scatter(X[100:],Y[100:], color='red', marker='+', label='Virginica')  # 后50个样本
plt.legend(loc=2)  # 图例显示在左上角
plt.grid()
plt.show()

# %% [markdown]
# （3）绘制箱型图

# %%
#设置图元参数

# %%
plt.rcParams['font.sans-serif'] = ['SimHei']  # 避免中文出现乱码
plt.rcParams['axes.unicode_minus'] = False

# %%
#准备数据

# %%
#随机产生一组取值为[50,90)之间,size值为(10,12)的整数，模拟上海市一年的平均相对湿度百分比

# %%
humidity = np.random.randint(50,90,(10,12)) #

# %%
#设置标签

# %%
labels = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sept', 'Oct', 'Nov', 'Dec']

# %%
#绘制箱型图

# %%
plt.boxplot(humidity, labels=labels, sym='*', whis=1.25, widths=0.6) #绘制箱型图
plt.xlabel('平均相对湿度百分比')  #设置x轴标签 
plt.show()

# %% [markdown]
# # 3. 综合分析题

# %% [markdown]
# （1）数据清洗

# %%
#读入文件RollerCoasterData.xlsx，该文件存放了世界各大乐园的著名的过山车的数据指标

# %%
df1=pd.read_excel(r'F:\JupyterNotebook\人工智能B\第六讲作业\RollerCoasterData.xlsx',sheet_name='RollerCoasterData')  #
df1
# Out:
# C:\Program Files\Python311\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)
#       ID                                    Name  \
# 0    1.0             10 Inversion Roller Coaster
# 1    2.0                                  Abismo
# 2    3.0                         Adrenaline Peak
# 3    4.0                               Afterburn
# 4    5.0                              Alpengeist
# ..   ...                                     ...
# 300  NaN                                     NaN
# 301  NaN                   Primary Data Sources:
# 302  NaN                       https://rcdb.com/
# 303  NaN  https://www.ultimaterollercoaster.com/
# 304  NaN               https://coasterpedia.net/
#
#                                 Park   City/Region     City/State/Region  \
# 0                 Chimelong Paradise         Panyu  Guangzhou, Guangdong
# ...

# %%
df1.drop(df1[df1.iloc[:,0].isnull()].index.append(df1[df1.iloc[:,11].isnull()].index), axis=0, inplace=True)#
df1
# Out:
#         ID                         Name                             Park  \
# 0      1.0  10 Inversion Roller Coaster               Chimelong Paradise
# 1      2.0                       Abismo  Parque de Atracciones de Madrid
# 2      3.0              Adrenaline Peak              Oaks Amusement Park
# 3      4.0                    Afterburn                        Carowinds
# 4      5.0                   Alpengeist       Busch Gardens Williamsburg
# ..     ...                          ...                              ...
# 295  296.0                     Wildfire                        Kolmarden
# 296  297.0                       Winjas                    Phantasialand
# 297  298.0         Wodan Timbur Coaster                      Europa Park
# 298  299.0                           X2         Six Flags Magic Mountain
# 299  300.0                   Xcelerator               Knott's Berry Farm
#
#       City/Region       City/State/Region Country/Region Geographic Region  \
# ...

# %%
#将“Height (feet)”列的值转为float

# %%
df1.iloc[:,11] = df1.iloc[:,11].astype('float64')  #
df1.iloc[:,11]
# Out:
# 0       98.40000
# 1      151.60000
# 2       72.00000
# 3      113.00000
# 4      195.00000
#          ...
# 295    183.80000
# 296     57.10000
# 297    131.30000
# 298    175.00000
# 299    145.26957
# Name: Height (feet), Length: 299, dtype: float64

# %%
#统计“Height (feet)”列的平均值(保留2位小数)
#提示：可用numpy模块的round函数，格式：round(数值，小数点位数)

# %%
ave_height = round(df1.iloc[:,11].mean(axis=0),2) #
ave_height
# Out:
# 135.52

# %%
#按国家/地区（Country/Region）分组统计不同国家/地区的过山车平均高度

# %%
CountryRegion = df1.groupby('Country/Region')   #按国家/地区（Country/Region）分组
print(CountryRegion)

# %%
df1.columns
# Out:
# Index(['ID', 'Name', 'Park', 'City/Region', 'City/State/Region',
#        'Country/Region', 'Geographic Region', 'Construction', 'Type', 'Status',
#        'Year/Date Opened', 'Height (feet)', ' Speed (mph)', 'Length (feet)',
#        'Inversions (YES or NO)', 'Number of Inversions', 'Drop (feet)',
#        'Duration (min:sec)', 'G Force', 'Vertical Angle (degrees)'],
#       dtype='object')

# %%
CountryRegion = df1.groupby('Country/Region')   #按国家/地区（Country/Region）分组
ch = CountryRegion['Height (feet)'].mean()  #按分组统计不同国家/地区的过山车平均高度
ch
# Out:
# Country/Region
# Argentina               112.900000
# Australia               242.800000
# Brazil                  115.300000
# Canada                  207.825000
# Chile                   112.900000
# China                   161.833333
# Colombia                 64.550000
# Costa Rica               64.000000
# Denmark                 101.700000
# Ecuador                  36.100000
# France                   98.975000
# Germany                 104.934483
# Italy                   150.933333
# Japan                   190.980000
# Mexico                  112.950000
# Poland                  252.600000
# Russia                   98.666667
# South Korea             165.750000
# Spain                   162.630000
# Sweden                  145.466667
# Turkey                  200.200000
# United Arab Emirates    188.650000
# United Kingdom          112.550000
# United States           136.696033
# Vietnam                 150.000000
# Name: Height (feet), dtype: float64

# %%
#画出各个国家过山车平均高度的条形图

# %%
# 画出各个国家过山车平均高度的条形图
fig, ax = plt.subplots(1, 1)
fig.set_size_inches(15, 5)
plt.rcParams['font.sans-serif'] = ['SimHei']
ax.set_xticks(np.arange(ch.size))
ax.set_xticklabels(ch.index, rotation=30, ha='right')
ax.set(title='各国家/地区过山车平均高度', xlabel='国家/地区', ylabel='高度（英尺）')
ax.bar(x=list(CountryRegion.groups.keys()), height=ch.values, color='green')
plt.show()

# %%
#统计表中各国家/地区过山车的数量

# %%
cc=CountryRegion.size()   #统计各国家/地区过山车的数量
cc
# Out:
# pandas.core.series.Series

# %%
#根据各国家/地区过山车的数量的占比绘制饼图

# %%
#根据各国家/地区过山车的数量的占比绘制饼图
fig = plt.figure(figsize=(12,12)) #设置画面大小为12*12英寸
plt.axis('equal') #设置xy轴等刻度
plt.pie(x=cc.tolist() ,autopct='%.1f%%',labels=list(CountryRegion.groups.keys()))  #画饼图
plt.legend(cc.index, title='过山车数量占比', bbox_to_anchor=(-0.15, 0.8),fontsize='xx-small', loc="center left") #显示图例
plt.show()
